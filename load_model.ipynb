# %%
import keras
import os
import glob
from skimage import io
import matplotlib.pyplot as plt
% matplotlib inline
import numpy as np
# Out:
# Using TensorFlow backend.
# UsageError: Line magic function `%` not found.

# %%
# function to plot n images using subplots
def plot_image(images, captions=None, cmap=None ):
    f, axes = plt.subplots(1, len(images), sharey=True)
    f.set_figwidth(15)
    for ax,image in zip(axes, images):
        ax.imshow(image, cmap)

# %%
from skimage.transform import rescale, resize, downscale_local_mean
image = io.imread("/home/shekhar/projects/MachineLearning/cleaned_dataset/dataset_resized_100/train/bedroom/383_bedroom.jpg")
plt.imshow(image)
#image_resized = resize(image, (100,100),
             #          anti_aliasing=True)
#plt.imshow(image_resized2

# %%
DATASET_PATH = "/home/shekhar/projects/MachineLearning/cleaned_dataset/dataset_compressed_256"
f_cls = ['apartment','kitchen','bathroom','bedroom','livingroom','mansion','bungalow']

# %%
im_path = os.path.join(DATASET_PATH, f_cls[3], '*')
print(im_path)

# glob through the directory (returns a list of all file paths)
im_path = glob.glob(im_path)
#print(im_path)
print(im_path[1]) # access an individual file
# Out:
# /home/shekhar/projects/MachineLearning/cleaned_dataset/dataset_compressed_256/bedroom/*
# /home/shekhar/projects/MachineLearning/cleaned_dataset/dataset_compressed_256/bedroom/60_bedroom.jpg

# %%
import random
rand_index = random.randint(0, len(im_path))
print(im_path[rand_index])
image = io.imread(im_path[rand_index])
print(type(image))
print(image.shape)
plt.imshow(image)
# Out:
# /home/shekhar/projects/MachineLearning/cleaned_dataset/dataset_compressed_256/bedroom/520_bedroom.jpg
# <class 'imageio.core.util.Array'>
# (256, 256, 3)

# %%
from skimage.transform import rescale, resize, downscale_local_mean
image_resized = resize(image, (100,100),
                   anti_aliasing=True)
print(type(image_resized))
plt.imshow(image_resized)
# Out:
# <class 'numpy.ndarray'>

# %%
model_path="/home/shekhar/projects/MachineLearning/models/single_model_for_all/100_100/model_may15_2020_evening_final.hdf5"
new_model = keras.models.load_model(model_path)

# %%
h, w, _ = image.shape
img = image[:,:, : ]

# %%
#import numpy as np
#y_prob =new_model.predict(image[np.newaxis,: ])
#print(y_prob)
#print(y_prob.argmax())

# %%
import numpy as np
y_prob =new_model.predict(image_resized[np.newaxis,: ])
print(y_prob)
print(y_prob.argmax())
# Out:
# [[2.01771082e-03 1.15713716e-04 5.48049994e-02 1.06889352e-01
#   7.59694636e-01 7.64776543e-02]]
# 4

# %% [markdown]
# 0=apartment
# 1= bungalow
# 2=kitchen
# 3 = bathroom
# 4=bedroom
# 5=livingroom

# %%
new_model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 100, 100, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 50, 50, 64)   9472        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 50, 50, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 50, 50, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# ...

# %%
from PIL import Image

# %%
im = Image.open(im_path[rand_index])

# %%
im.thumbnail((100,100), Image.ANTIALIAS)
im.save("/home/shekhar/Downloads/sample.thumbnail", "JPEG")

# %%
d = Image.open("/home/shekhar/Downloads/sample.thumbnail")
plt.imshow(d)

# %%
x =5
y=2
print (300//32)
# Out:
# 9
